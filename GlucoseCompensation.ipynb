# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Simulating-Dark-Expressions-ad-Interactions-of-frq-and-wc-1-in-the-Neurospora-Circadian-Clock" data-toc-modified-id="Simulating-Dark-Expressions-ad-Interactions-of-frq-and-wc-1-in-the-Neurospora-Circadian-Clock-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Simulating Dark Expressions ad Interactions of <em>frq</em> and <em>wc-1</em> in the <em>Neurospora</em> Circadian Clock</a></span><ul class="toc-item"><li><span><a href="#Abstract" data-toc-modified-id="Abstract-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Abstract</a></span></li><li><span><a href="#Wiring-diagram-for-Neurospora-clock" data-toc-modified-id="Wiring-diagram-for-Neurospora-clock-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Wiring diagram for <em>Neurospora</em> clock</a></span><ul class="toc-item"><li><span><a href="#Simplified-wiring-diagram-for-Neurospora-clock" data-toc-modified-id="Simplified-wiring-diagram-for-Neurospora-clock-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Simplified wiring diagram for <em>Neurospora</em> clock</a></span></li></ul></li><li><span><a href="#Molecular-pathway-for-Neurospora-clock" data-toc-modified-id="Molecular-pathway-for-Neurospora-clock-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Molecular pathway for <em>Neurospora</em> clock</a></span></li><li><span><a href="#Rate-equations-for-Neurospora-clock" data-toc-modified-id="Rate-equations-for-Neurospora-clock-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Rate equations for <em>Neurospora</em> clock</a></span><ul class="toc-item"><li><span><a href="#Tellurium-rate-equations-for-Neurospora-clock" data-toc-modified-id="Tellurium-rate-equations-for-Neurospora-clock-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>Tellurium rate equations for <em>Neurospora</em> clock</a></span></li></ul></li><li><span><a href="#Rate-constants-and-activation-energies-for-Neurospora-clock" data-toc-modified-id="Rate-constants-and-activation-energies-for-Neurospora-clock-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Rate constants and activation energies for <em>Neurospora</em> clock</a></span><ul class="toc-item"><li><span><a href="#Tellurium-rate-constants-and-activation-energies-for-Neurospora-clock" data-toc-modified-id="Tellurium-rate-constants-and-activation-energies-for-Neurospora-clock-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>Tellurium rate constants and activation energies for <em>Neurospora</em> clock</a></span></li></ul></li><li><span><a href="#Simulation-results-for-Neurospora-clock" data-toc-modified-id="Simulation-results-for-Neurospora-clock-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Simulation results for <em>Neurospora</em> clock</a></span><ul class="toc-item"><li><span><a href="#Tellurium-initial-values-for-Neurospora-clock" data-toc-modified-id="Tellurium-initial-values-for-Neurospora-clock-1.6.1"><span class="toc-item-num">1.6.1&nbsp;&nbsp;</span>Tellurium initial values for <em>Neurospora</em> clock</a></span></li><li><span><a href="#Tellurium-simulation-results-for-Neurospora-clock" data-toc-modified-id="Tellurium-simulation-results-for-Neurospora-clock-1.6.2"><span class="toc-item-num">1.6.2&nbsp;&nbsp;</span>Tellurium simulation results for <em>Neurospora</em> clock</a></span></li></ul></li></ul></li><li><span><a href="#Wiring-diagram-for-glucose-compensation-in-the-Neurospora-clock" data-toc-modified-id="Wiring-diagram-for-glucose-compensation-in-the-Neurospora-clock-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Wiring diagram for glucose compensation in the <em>Neurospora</em> clock</a></span><ul class="toc-item"><li><span><a href="#Molecular-pathway-for-glucose-compensation-in-Neurospora-clock" data-toc-modified-id="Molecular-pathway-for-glucose-compensation-in-Neurospora-clock-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Molecular pathway for glucose compensation in <em>Neurospora</em> clock</a></span></li><li><span><a href="#Rate-equations-for-glucose-compensation-in-Neurospora-clock" data-toc-modified-id="Rate-equations-for-glucose-compensation-in-Neurospora-clock-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Rate equations for glucose compensation in <em>Neurospora</em> clock</a></span></li><li><span><a href="#Rate-constants-for-glucose-compensation-in-Neurospora--clock" data-toc-modified-id="Rate-constants-for-glucose-compensation-in-Neurospora--clock-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Rate constants for glucose compensation in <em>Neurospora</em>  clock</a></span></li><li><span><a href="#Stochastic-equations-for-glucose-compensation-in-Neurospora-clock" data-toc-modified-id="Stochastic-equations-for-glucose-compensation-in-Neurospora-clock-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Stochastic equations for glucose compensation in <em>Neurospora</em> clock</a></span></li></ul></li><li><span><a href="#Alternate-formulations-for-Neurospora-clock" data-toc-modified-id="Alternate-formulations-for-Neurospora-clock-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Alternate formulations for <em>Neurospora</em> clock</a></span></li></ul></div>

# %% [markdown]
# # Simulating Dark Expressions ad Interactions of *frq* and *wc-1* in the *Neurospora* Circadian Clock #
#
# Hong, Christian I, Jolma, Ingunn W, Loros, Jennifer J, Dunlap, Jay C, Ruoff, Peter "[Simulating Dark Expressions ad Interactions of *frq* and *wc-1* in the *Neurospora* Circadian Clock](http://linkinghub.elsevier.com/retrieve/pii/S0006349508706404)" *Biophysical Journal* 2008, 94:4 1221-1232
#
# ## Abstract ##
# Circadian rhythms are considered to play an essential part in the adaptation of organisms to their environments. The occurrence of circadian oscillations appears to be based on the presence of transcriptional-translational negative feedback loops. In Neurospora crassa, the protein FREQUENCY (FRQ) is part of such a negative feedback loop apparently by a direct interaction with its transcription factor WHITE COLLAR-1 (WC-1). Based on the observation that nuclear FRQ levels are significantly lower than nuclear WC-1 levels, it was suggested that FRQ would act more like a catalyst in inhibiting WC-1 rather than binding to WC-1 and making an inactive FRQ:WC-1 complex. Intrigued by this hypothesis, we constructed a model for the Neurospora circadian clock, which includes expression of the frq and the wc-1 genes and their possible interactions. The model suggests that even small amounts of nuclear FRQ-protein are capable of inhibiting frq transcription in a rhythmic manner by binding to WC-1 and promoting its degradation. Our model predicts the importance of a FRQ dependent degradation of WC-1 in closing the negative feedback loop. The model shows good agreement with experimental levels in nuclear and cytosolic FRQ and WC-1, their phase relationships, and several clock mutant phenotypes.

# %% [markdown]
# ## Wiring diagram for *Neurospora* clock ##

# %%
from IPython.display import Image

Image('Clock/WiringDiagramForNeurosporaClock.png')

# %% [markdown]
# ### Simplified wiring diagram for *Neurospora* clock ###

# %%
Image('Clock/SimplifiedWiringDiagramForNeurosporaClock.png')

# %% [markdown]
# ## Molecular pathway for *Neurospora* clock ##

# %%
Image('Clock/FRQ-WC-1-formation-degradation.jpg')

# %% [markdown]
# ## Rate equations for *Neurospora* clock ##

# %%
Image('Clock/CircadianClockEquations.png')

# %% [markdown]
# ### Tellurium rate equations for *Neurospora* clock ###

# %%
# %matplotlib inline
import tellurium as te


circadian_clock_rate_eqns = '''
    frq_mRNA'          = k1*(WC1n^2)/(K + WC1n^2) - k4*frq_mRNA + k01 ;
    FRQc'              = k2*frq_mRNA - (k3 + k5)*FRQc ;
    FRQn'              = k3*FRQc + k14*FRQn_WC1n_complex - FRQn*(k6 + k13*WC1n) ;
    wc1_mRNA'          = k7 - k10*wc1_mRNA ;
    WC1c'              = k8*FRQc*wc1_mRNA/(K2 + FRQc) - (k9 + k11)*WC1c + k02*wc1_mRNA ;
    WC1n'              = k9*WC1c - WC1n*(k12 + k13*FRQn) + k14*FRQn_WC1n_complex ;
    FRQn_WC1n_complex' = k13*FRQn*WC1n - (k14 + k15)*FRQn_WC1n_complex ; \n''' 

circadian_clock_parameters = '\n'.join(['k%d = {k%d} ;' % (i+1,i+1) for i in range(15)]) + '''
    k01 = {k01} ;
    k02 = {k02} ;
    K = {K} ;
    K2 = {K2} ;
    '''

# %% [markdown]
# ## Rate constants and activation energies for *Neurospora* clock ##

# %%
Image('Clock/Table-1-RateConstants-and-Activation-Energies.jpg')

# %% [markdown]
# ### Tellurium rate constants and activation energies for *Neurospora* clock ###

# %%
import pandas as pd
table1 = pd.DataFrame({
    'k01': 0.02,
    'k02': 0.001,
    'k1': 1.8,
    'k2': 1.8,
    'k3': {'frq+':0.05, 'Frq^1':0.15, 'Frq^7':0.05, 'frq^{S513I}':0.05},
    'k4': 0.23,
    'k5':{'frq+':0.27, 'Frq^1':0.4, 'Frq^7':0.15, 'frq^{S513I}':0.1},
    'k6': {'frq+':0.07, 'Frq^1':0.1, 'Frq^7':0.01, 'frq^{S513I}':0.006},
    'k7':0.16,
    'k8': 0.8,
    'k9':40.0,
    'k10':0.1,
    'k11':0.05,
    'k12': 0.02,
    'k13': 50.0,
    'k14': 1.0,
    'k15':5.0,
    'K': {'frq+':1.25,'ER24': 8.5 },
    'K2': 1.0,
    'E1': 62.6,
    'E2': 20.9,
    'E3':25.4,
    'E4': 15.2,
    'E5': {},
    'E6': 31.9,
    'E7': 104,
    'E8': 22.0,
    'E9': 66.2,
    'E10': 30.0,
    'E11':50.6,
    'E12': 25.4,
    'E13': 58.6,
    'E14': 50.2,
    'E15': 50.4,
    'EK': {},
    'EK2': 68.8
    }).T
table1
# Out:
#         ER24    Frq^1    Frq^7     frq+  frq^{S513I}
# E1    62.600   62.600   62.600   62.600       62.600
# E10   30.000   30.000   30.000   30.000       30.000
# E11   50.600   50.600   50.600   50.600       50.600
# E12   25.400   25.400   25.400   25.400       25.400
# E13   58.600   58.600   58.600   58.600       58.600
# E14   50.200   50.200   50.200   50.200       50.200
# E15   50.400   50.400   50.400   50.400       50.400
# E2    20.900   20.900   20.900   20.900       20.900
# E3    25.400   25.400   25.400   25.400       25.400
# E4    15.200   15.200   15.200   15.200       15.200
# E5       NaN      NaN      NaN      NaN          NaN
# E6    31.900   31.900   31.900   31.900       31.900
# E7   104.000  104.000  104.000  104.000      104.000
# E8    22.000   22.000   22.000   22.000       22.000
# E9    66.200   66.200   66.200   66.200       66.200
# EK       NaN      NaN      NaN      NaN          NaN
# EK2   68.800   68.800   68.800   68.800       68.800
# ...

# %% [markdown]
# ## Simulation results for *Neurospora* clock ##

# %% [markdown]
# ### Tellurium initial values for *Neurospora* clock ###

# %%
circadian_clock_initial_values = '''
    frq_mRNA = {frq_mRNA} ;
    FRQc     = {FRQc} ;
    FRQn     = {FRQn} ;
    wc1_mRNA = {wc1_mRNA} ;
    WC1c     = {WC1c} ;
    WC1n     = {WC1n} ;
    FRQn_WC1n_complex = {FRQn_WC1n_complex} ;
'''

figureS3_initial_concentrations = {'frq_mRNA': 4.3e-6,
                                  'FRQc': 2.44e-5,
                                  'FRQn': 3.14e-7,
                                  'wc1_mRNA': 1.67,
                                  'WC1c': 4.24e-5,
                                  'WC1n': 8.58e-2,
                                  'FRQn_WC1n_complex': 1.5e-7}
figure2A_initial_concentrations = {'frq_mRNA': 4,
                                  'FRQc': 2.44e1,
                                  'FRQn': 3.14,
                                  'wc1_mRNA': 1.8,
                                  'WC1c': 4.24e-3,
                                  'WC1n': 5.58e-1,
                                  'FRQn_WC1n_complex': 1.5}

# %% [markdown]
# ### Tellurium simulation results for *Neurospora* clock ###

# %%
import roadrunner
dir(result)
# Out:
# ['T',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_finalize__',
#  '__array_interface__',
#  '__array_prepare__',
#  '__array_priority__',
#  '__array_struct__',
#  '__array_wrap__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__delslice__',
#  '__div__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getslice__',
#  '__gt__',
#  '__hash__',
#  '__hex__',
#  '__iadd__',
#  '__iand__',
#  '__idiv__',
#  '__ifloordiv__',
#  '__ilshift__',
#  '__imod__',
#  '__imul__',
#  '__index__',
#  '__init__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__irshift__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lshift__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
# ...

# %%
circadian_clock = te.loada( circadian_clock_rate_eqns + \
                            circadian_clock_parameters.format( 
                                **table1['frq+'].to_dict() ) + \
                            circadian_clock_initial_values.format( 
                                **figure2A_initial_concentrations ))
result = circadian_clock.simulate( 0, 100, 5000)
circadian_clock.plot( result,ylim=[0,20],ylabel='Concentration',title='Figure 2A' );

# %%
Image('Clock/Figure2A.png')

# %%
circadian_clock = te.loada( circadian_clock_rate_eqns + \
                            circadian_clock_parameters.format( **table1['frq+'].to_dict() ) + \
                            circadian_clock_initial_values.format( **figureS3_initial_concentrations ))
result = circadian_clock.simulate( 0, 48, 5000)
circadian_clock.draw(width=200)
circadian_clock.plot( result,ylim=[0,100], );

# %% [markdown]
# # Wiring diagram for glucose compensation in the *Neurospora* clock #

# %%
Image('Clock/GlucoseCompensationWiringDiagram.png')

# %%
Image('Clock/GlucoseCompensation.png')

# %% [markdown]
# ## Molecular pathway for glucose compensation in *Neurospora* clock ##

# %%
Image('Clock/glucose_compensation.jpg')

# %% [markdown]
# ## Rate equations for glucose compensation in *Neurospora* clock ##

# %%
Image('Clock/GlucoseCompensationRateEqns1.png')
glucose_compensation_rate_eqns = '''
    frq_mRNA' = k1*WC1n^6/(K+WC1n^6) - k4*frq_mRNA + k01 ;
    FRQc' = k2*frq_mRNA - (k3 + k5)*FRQc ;
    FRQn' = k3*FRQc + k14*FRQn_WC1n_complex - FRQn*(k6+k13*WC1n) ;
    wc1_mRNA' = k7*K1/(K1 + CSP1)  - k10*wc1_mRNA + k03 ;
    WC1c' = k8*FRQc^2/(K2 + FRQc^2)*wc1_mRNA/(K3 + wc1_mRNA) - (k9 + k11)* WC1c ;
    WC1n' = k9*WC1c - WC1n*(k12+k13*FRQn + k14*FRQn_WC1n_complex ;
    FRQn_WC1_complex' = k13*FRQn*WC1n - (k14+k15)*FRQn_WC1n_complex ;
    csp1_mRNA' = k16*WC1n*K4/(K4 + CSP1) - k17*csp1_mRNA + k04 ;
    CSP1' = k18*csp1_mRNA - k19*CSP1 ;
'''

# %%
Image('Clock/GlucoseCompensationRateEqns2.png')

# %% [markdown]
# ## Rate constants for glucose compensation in *Neurospora*  clock##

# %%
glucose_compensation_table = pd.DataFrame( {
    'Parameter': ['k{}'.format(i+1) for i in range(19)] + \
                ['K'] + ['K{}'.format(i+1) for i in range(4)],
    'Value': [1.8,1.8,0.05,0.23,0.27, 0.27, 0.5,1,40,0.1,0.05,0.02,50,1,5,0.12,1.4,50,1.4,1.25,3,1,10,3],
    'Dimension': ['$a.u.\ h^{-1}$','$h^{-1}$','$h^{-1}$','$h^{-1}$','$h^{-1}$', '$h^{-1}$','$a.u.\ h^{-1}$','$a.u.\ h^{-1}$','$h^{-1}$','$h^{-1}$','$h^{-1}$','$h^{-1}$',
                 '$(a.u.)^{-1}h^{-1}$','$h^{-1}$','$h^{-1}$','$h^{-1}$','$h^{-1}$','$h^{-1}$','$h^{-1}$','$(a.u.)^6$',
                 '$a.u.$','$(a.u.)^2$','$a.u.$','$a.u.$']})
glucose_compensation_table[['Parameter','Value','Dimension']]
#
# Out:
#    Parameter  Value            Dimension
# 0         k1   1.80       $a.u.\ h^{-1}$
# 1         k2   1.80             $h^{-1}$
# 2         k3   0.05             $h^{-1}$
# 3         k4   0.23             $h^{-1}$
# 4         k5   0.27             $h^{-1}$
# 5         k6   0.27             $h^{-1}$
# 6         k7   0.50       $a.u.\ h^{-1}$
# 7         k8   1.00       $a.u.\ h^{-1}$
# 8         k9  40.00             $h^{-1}$
# 9        k10   0.10             $h^{-1}$
# 10       k11   0.05             $h^{-1}$
# 11       k12   0.02             $h^{-1}$
# 12       k13  50.00  $(a.u.)^{-1}h^{-1}$
# 13       k14   1.00             $h^{-1}$
# 14       k15   5.00             $h^{-1}$
# 15       k16   0.12             $h^{-1}$
# 16       k17   1.40             $h^{-1}$
# 17       k18  50.00             $h^{-1}$
# 18       k19   1.40             $h^{-1}$
# 19         K   1.25           $(a.u.)^6$
# 20        K1   3.00               $a.u.$
# 21        K2   1.00           $(a.u.)^2$
# ...

# %%
Image('Clock/Table-1-glucose-compensation-rate-parameters.png')

# %% [markdown]
# ## Stochastic equations for glucose compensation in *Neurospora* clock ##

# %%
Image('Clock/StochasticRxnEqns.png')

# %%
from IPython.display import HTML
StochasticRxnEqns = pd.DataFrame({'Reaction number': [i+1 for i in range(10)],
                                 'Reaction':['G -> frq_mRNA + G ;',
                                            'frq_mRNA -> ;',
                                            'frq_mRNA -> FRQc + frq_mRNA ;',
                                            'FRQc -> FRQn ;',
                                            'FRQc -> ;',
                                            'FRQn_WC1_complex -> FRQn + WC1n ;',
                                            'FRQn -> ;',
                                            'FRQn + WC1n -> FRQn_WC1n_complex ;',
                                            'H -> wc1_mRNA + H ;',
                                            'wc1_mRNA -> ;'],
                                 'Probability of reaction':[
                                     'k1*Omega*WC1n^6/(K*Omega^6 + WC1n^6) ;',
                                     'k4*frq_mRNA ;',
                                     'k2*frq_mRNA ;',
                                     'k3*FRQc ;',
                                     'k5*FRQc ;',
                                     'k14*FRQn_WC1n_complex ;',
                                     'k6*FRQn ;',
                                     '(k13/Omega)*FRQn*WC1n ;',
                                     'k7*Omega*K1*Omega/(K1*Omega+CSP1) ;',
                                     'k10*wc1_mRNA',],
                                  'Reaction Equation': [
                                      '$k_1\Omega \frac{\mbox{WC-1}_n^6}{K\Omega^6 + \mbox{WC-1}_n^6 }$',
                                     '$k_4\ frq\mbox{ mRNA}$',
                                     '$k_2\ frq\mbox{ mRNA}$',
                                     '$k_3\ \mbox{FRQ}_c$',
                                     '$k_5\ \mbox{FRQ}_c$',
                                     '$k_{14}\ \mbox{FRQ}_n:\mbox{WC-1}_n$',
                                     '$k_6\ \mbox{FRQ}_n$',
                                     '$$\frac{k_{13}}{\Omega}\mbox{ FRQ}_n\mbox{ WC-1}_n$$',
                                     '$\left(k_7\ \Omega K_1\right)\frac{\Omega}{K_1\Omega + \mbox{CSP-1}}$',
                                     '$k_{10}\ wc1\mbox{ mRNA}$',]})
                                  
                                                           
HTML(StochasticRxnEqns.set_index('Reaction number').to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Probability of reaction</th>
#       <th>Reaction</th>
#       <th>Reaction Equation</th>
#     </tr>
#     <tr>
#       <th>Reaction number</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>k1*Omega*WC1n^6/(K*Omega^6 + WC1n^6) ;</td>
#       <td>G -&gt; frq_mRNA + G ;</td>
#       <td>$k_1\Omega rac{\mbox{WC-1}_n^6}{K\Omega^6 + \...</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>k4*frq_mRNA ;</td>
#       <td>frq_mRNA -&gt; ;</td>
#       <td>$k_4\ frq\mbox{ mRNA}$</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>k2*frq_mRNA ;</td>
#       <td>frq_mRNA -&gt; FRQc + frq_mRNA ;</td>
#       <td>$k_2\ frq\mbox{ mRNA}$</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>k3*FRQc ;</td>
#       <td>FRQc -&gt; FRQn ;</td>
#       <td>$k_3\ \mbox{FRQ}_c$</td>
# ...

# %% [markdown]
# # Alternate formulations for *Neurospora* clock #

# %%
Image('Clock/FRQ-inhibits-WC-1.jpg')

# %%
Image('Clock/Fig1B_rate_eqns.png')
fig1b_rate_eqns = '''
    frq_mRNA' = k1*(WC1n^2)/(K+WC1n^2) - k4*frq_mRNA + k01 ;
    FRQc' = k2*frq_mRNA - (k3+k5)*FRQc ;
    FRQn' = k3*FRQc + (k17 + k18)*FRQn_WC1n_complex  - FRQn*(k6 + k16*WC1n) ;
    wc1_mRNA' = k7 - k10*wc1_mRNA ;
    WC1c' = k8*FRQc*wc1_mRNA/(K2 + FRQc) - (k9+k11)*WC1c + k02*wc1_mRNA ;
    WC1n' =k9*WC1c - WC1n*(k12 + k16*FRQn) + k17*FRQn_WC1n_complex ;
    FRQn_WC1n_complex' = k16*FRQn*WC1n - (k17+k18+k20)*FRQn_WC1n_complex ;
    WC1n' = k18*FRQ_WC1n_complex - k19* WC1n ;
'''

# %%
Image('Clock/Fig1C_rate_eqns.png')
fig1c_rate_eqns = '''
    frq_mRNA' = k1*(WC1n^2)/(K+WC1n^2) - k4*frq_mRNA + k01 ;
    FRQc' = k2*frq_mRNA - (k3+k5)*FRQc ;
    FRQn' = k3*FRQc + k17*FRQn_WC1n_complex - FRQn*(k6+k16*WC1n) ;
    wc1_mRNA' = k7 - k10*wc1_mRNA ;
    WC1c' = k8*FRQc*wc1_mRNA/(K2 + FRQc) - (k9+k11)*WC1c + k02*wc1_mRNA ;
    WC1n' =k9*WC1c - WC1n*(k12 + k16*FRQn) + k17*FRQn_WC1n_complex ;
    FRQn_WC1n_complex' = k16*FRQn*WC1n - (k17+k18+k20)*FRQn_WC1n_complex ;
    inactive_WC1n' = k18*FRQ_WC1n - k19* inactive_WC1n ;
    inactive_FRQn' = k18*FRQn_WC1n - k21*inactive_FRQn ;
    
'''

# %%
Image('Clock/1C-kinetically-equivalent-to-1A.jpg')
